# %%
import numpy 
import pandas
import matplotlib

# %%
dataset = pandas.read_csv('owid-covid-data_top10.csv', sep=',', encoding='utf-8')

# %%
dataset.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      BRA  South America   Brazil  2020-02-26          1.0        1.0
# 1      BRA  South America   Brazil  2020-02-27          1.0        0.0
# 2      BRA  South America   Brazil  2020-02-28          1.0        0.0
# 3      BRA  South America   Brazil  2020-02-29          2.0        1.0
# 4      BRA  South America   Brazil  2020-03-01          2.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
dataset.tail()
# Out:
#      iso_code      continent       location        date  total_cases  \
# 7658      USA  North America  United States  2022-03-01   79091361.0
# 7659      USA  North America  United States  2022-03-02   79143716.0
# 7660      USA  North America  United States  2022-03-03   79196008.0
# 7661      USA  North America  United States  2022-03-04   79250509.0
# 7662      USA  North America  United States  2022-03-05   79265726.0
#
#       new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 7658    47031.0           62331.429      952423.0      1691.0
# 7659    52355.0           57824.857      954518.0      2095.0
# 7660    52292.0           55673.857      956261.0      1743.0
# 7661    54501.0           52764.286      958144.0      1883.0
# 7662    15217.0           47989.857      958437.0       293.0
#
#       new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 7658             1830.000  ...            19.1          24.6
# ...

# %%
dataset.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed   total_deaths  \
# count  7.663000e+03  7.641000e+03         7484.000000    7345.000000
# mean   7.413453e+06  3.248569e+04        32590.349244  143683.851464
# std    1.200763e+07  6.990790e+04        66130.926542  193260.956591
# min    1.000000e+00  0.000000e+00            0.000000       1.000000
# 25%    2.297820e+05  1.333000e+03         1440.107250   10145.000000
# 50%    2.702681e+06  9.921000e+03        11149.928500   83976.000000
# 75%    7.906961e+06  3.357100e+04        35266.357250  149512.000000
# max    7.926573e+07  1.368167e+06       802518.429000  958437.000000
#
#         new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  7327.000000          7173.000000              7663.000000
# mean    420.451071           423.776663             40129.002883
# std     656.855964           611.463015             53182.233431
# min       0.000000             0.000000                 0.001000
# ...

# %%
dataset[(dataset['location'] == 'Brazil') & (dataset['date'] == '2020-03-01')]
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 4      BRA  South America   Brazil  2020-03-01          2.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 4            10.1          17.9                     NaN
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 4                         2.2            75.88                    0.765
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 4               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
dataset['new_cases_porcentage'] = dataset['new_cases'] / dataset['total_cases'] * 100

# %%
dataset.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      BRA  South America   Brazil  2020-02-26          1.0        1.0
# 1      BRA  South America   Brazil  2020-02-27          1.0        0.0
# 2      BRA  South America   Brazil  2020-02-28          1.0        0.0
# 3      BRA  South America   Brazil  2020-02-29          2.0        1.0
# 4      BRA  South America   Brazil  2020-03-01          2.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
dataset['new_cases_porcentage']
# Out:
# 0       100.000000
# 1         0.000000
# 2         0.000000
# 3        50.000000
# 4         0.000000
#            ...
# 7658      0.059464
# 7659      0.066152
# 7660      0.066029
# 7661      0.068771
# 7662      0.019197
# Name: new_cases_porcentage, Length: 7663, dtype: float64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7663 entries, 0 to 7662
# Data columns (total 68 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    7663 non-null   object
#  1   continent                                   7663 non-null   object
#  2   location                                    7663 non-null   object
#  3   date                                        7663 non-null   object
#  4   total_cases                                 7663 non-null   float64
#  5   new_cases                                   7641 non-null   float64
#  6   new_cases_smoothed                          7484 non-null   float64
#  7   total_deaths                                7345 non-null   float64
#  8   new_deaths                                  7327 non-null   float64
# ...

# %%
dataset['log_total_cases'] = numpy.log(dataset['total_cases'])

# %%
dataset.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      BRA  South America   Brazil  2020-02-26          1.0        1.0
# 1      BRA  South America   Brazil  2020-02-27          1.0        0.0
# 2      BRA  South America   Brazil  2020-02-28          1.0        0.0
# 3      BRA  South America   Brazil  2020-02-29          2.0        1.0
# 4      BRA  South America   Brazil  2020-03-01          2.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# ...

# %%
dataset.to_csv('covidgripizinhabraba', sep=',', encoding='utf-8')
